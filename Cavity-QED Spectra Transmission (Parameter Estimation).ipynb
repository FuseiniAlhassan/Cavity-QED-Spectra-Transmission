# %%
# Cavity-QED Transmission: Parameter Estimation from Spectra
import os, json, math, random, pathlib
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, Model

# Reproducibility
SEED = 23
np.random.seed(SEED); random.seed(SEED); tf.random.set_seed(SEED)

try:
    if tf.config.list_physical_devices('GPU'):
        tf.keras.mixed_precision.set_global_policy('mixed_float16')
        print("Using mixed precision.")
except Exception as e:
    print("AMP not enabled:", e)

# Simple input-output theory (one atom)
# Transmission ~ | κ_ext / (iΔ + κ/2 + g^2/(iΔ + γ/2)) |^2
# We simulate over detuning Δ around resonance.

def cavity_transmission(delta, g, kappa, gamma, kappa_ext=None):
    # All in angular frequency units (arbitrary consistent units)
    if kappa_ext is None:
        kappa_ext = 0.6*kappa
    denom = 1j*delta + kappa/2.0 + (g**2)/(1j*delta + gamma/2.0)
    t = kappa_ext / denom
    return np.abs(t)**2

def synth_spectrum(num_points=256):
    # Sample physically plausible ranges (arbitrary units)
    g     = np.random.uniform(0.5, 5.0)       # coupling
    kappa = np.random.uniform(1.0, 8.0)       # cavity linewidth
    gamma = np.random.uniform(0.2, 3.0)       # atomic linewidth
    # Detuning sweep
    span = np.random.uniform(6.0, 14.0)
    delta = np.linspace(-span, span, num_points)
    spec = cavity_transmission(delta, g, kappa, gamma)
    # Normalize and add noise
    spec = spec / (spec.max()+1e-9)
    snr = np.random.uniform(20, 40)  # dB
    p_sig = np.mean(spec**2)
    p_noise = p_sig / (10**(snr/10))
    spec_noisy = spec + np.random.normal(0, np.sqrt(p_noise), spec.shape)
    spec_noisy = np.clip(spec_noisy, 0.0, 1.0).astype(np.float32)
    return spec_noisy, np.array([g, kappa, gamma], dtype=np.float32), delta.astype(np.float32)

def make_dataset(num=12000, L=256):
    X = np.zeros((num, L, 1), dtype=np.float32)
    Y = np.zeros((num, 3), dtype=np.float32)  # [g, kappa, gamma]
    DELTA = np.zeros((num, L), dtype=np.float32)
    for i in range(num):
        s, p, d = synth_spectrum(L)
        X[i,:,0] = s
        Y[i,:] = p
        DELTA[i,:] = d
    return X, Y, DELTA

# Quick peek
s, p, d = synth_spectrum(256)
plt.figure(figsize=(5,3))
plt.plot(d, s)
plt.title(f"Spectrum (g={p[0]:.2f}, κ={p[1]:.2f}, γ={p[2]:.2f})")
plt.xlabel("Δ")
plt.ylabel("T")
plt.tight_layout()
plt.savefig("figure")
plt.show()


# Data

L = 256
N_TR, N_VA, N_TE = 9000, 1500, 1500
X, Y, DEL = make_dataset(N_TR+N_VA+N_TE, L)
X_tr, X_va, X_te = np.split(X, [N_TR, N_TR+N_VA])
Y_tr, Y_va, Y_te = np.split(Y, [N_TR, N_TR+N_VA])
D_tr, D_va, D_te = np.split(DEL, [N_TR, N_TR+N_VA])

BATCH=64; AUTOTUNE=tf.data.AUTOTUNE
ds_tr = tf.data.Dataset.from_tensor_slices((X_tr, Y_tr)).shuffle(4096, seed=SEED).batch(BATCH).prefetch(AUTOTUNE)
ds_va = tf.data.Dataset.from_tensor_slices((X_va, Y_va)).batch(BATCH).prefetch(AUTOTUNE)
ds_te = tf.data.Dataset.from_tensor_slices((X_te, Y_te)).batch(BATCH).prefetch(AUTOTUNE)


# Model: lightweight 1D CNN regressor

def build_cnn_1d(input_shape=(256,1)):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv1D(32, 7, padding='same')(inp); x = layers.LeakyReLU(0.1)(x)
    x = layers.Conv1D(32, 7, padding='same')(x);   x = layers.LeakyReLU(0.1)(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding='same')(x); x = layers.LeakyReLU(0.1)(x)
    x = layers.Conv1D(64, 5, padding='same')(x); x = layers.LeakyReLU(0.1)(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(128, 3, padding='same')(x); x = layers.LeakyReLU(0.1)(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    out = layers.Dense(3, activation='linear', dtype='float32')(x)  # [g, kappa, gamma]
    return Model(inp, out)

model = build_cnn_1d((L,1))
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(2e-3), loss='mse', metrics=['mae'])

out_dir = pathlib.Path("artifacts_cavity_qed"); out_dir.mkdir(exist_ok=True)
ckpt = tf.keras.callbacks.ModelCheckpoint(str(out_dir/"best_cqed.keras"), monitor='val_loss', save_best_only=True)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

hist = model.fit(ds_tr, validation_data=ds_va, epochs=80, callbacks=[ckpt, es, rlr])
with open(out_dir/"history.json","w") as f:
    json.dump({k:[float(x) for x in v] for k,v in hist.history.items()}, f)


# Evaluation & Visualization

metrics = model.evaluate(ds_te, return_dict=True)
print(metrics)

# Show a few predicted vs true spectra parameters
xb, yb = next(iter(ds_te))
yp = model.predict(xb)
for i in range(3):
    gT,kT,gamT = yb[i].numpy()
    gP,kP,gamP = yp[i]
    plt.figure(figsize=(5,3))
    # Rebuild spectra from predictions and truth on the same detuning grid
    d = D_te[i]
    s_true = cavity_transmission(d, gT, kT, gamT)
    s_true /= s_true.max()+1e-9
    s_pred = cavity_transmission(d, gP, kP, gamP)
    s_pred /= s_pred.max()+1e-9
    plt.plot(d, xb[i,:,0], label="Noisy sim (input)", alpha=0.5)
    plt.plot(d, s_true, label=f"Truth (g={gT:.2f}, κ={kT:.2f}, γ={gamT:.2f})")
    plt.plot(d, s_pred, '--', label=f"Pred (g={gP:.2f}, κ={kP:.2f}, γ={gamP:.2f})")
    plt.legend()
    plt.xlabel("Detuning Δ")
    plt.ylabel("Transmission")
    plt.tight_layout()
    plt.savefig("figure")
    plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 256, 1)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 256, 32)             │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 256, 32)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 256, 32)             │           7,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 256, 32)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 128, 32)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 128, 64)             │          10,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 128, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 128, 64)             │          20,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 128, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 64, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 64, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 64, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,907 (312.14 KB)
#  Trainable params: 79,907 (312.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - loss: 2.1256 - mae: 1.1232 - val_loss: 1.2614 - val_mae: 0.9114 - learning_rate: 0.0020
# Epoch 2/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 154ms/step - loss: 1.1689 - mae: 0.8774 - val_loss: 1.1268 - val_mae: 0.8638 - learning_rate: 0.0020
# Epoch 3/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 1.0919 - mae: 0.8450 - val_loss: 1.0028 - val_mae: 0.8065 - learning_rate: 0.0020
# Epoch 4/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - loss: 0.9237 - mae: 0.7683 - val_loss: 0.7851 - val_mae: 0.7032 - learning_rate: 0.0020
# Epoch 5/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - loss: 0.6825 - mae: 0.6410 - val_loss: 0.6597 - val_mae: 0.6180 - learning_rate: 0.0020
# Epoch 6/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 152ms/step - loss: 0.5059 - mae: 0.5380 - val_loss: 0.4609 - val_mae: 0.5102 - learning_rate: 0.0020
# Epoch 7/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - loss: 0.4409 - mae: 0.5004 - val_loss: 0.4199 - val_mae: 0.4914 - learning_rate: 0.0020
# Epoch 8/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 155ms/step - loss: 0.4090 - mae: 0.4787 - val_loss: 0.3912 - val_mae: 0.4746 - learning_rate: 0.0020
# Epoch 9/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 156ms/step - loss: 0.3878 - mae: 0.4652 - val_loss: 0.4598 - val_mae: 0.5056 - learning_rate: 0.0020
# Epoch 10/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 22s 156ms/step - loss: 0.3848 - mae: 0.4621 - val_loss: 0.3655 - val_mae: 0.4546 - learning_rate: 0.0020
# Epoch 11/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - loss: 0.3672 - mae: 0.4537 - val_loss: 0.3887 - val_mae: 0.4606 - learning_rate: 0.0020
# Epoch 12/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.3710 - mae: 0.4543 - val_loss: 0.3914 - val_mae: 0.4729 - learning_rate: 0.0020
# Epoch 13/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - loss: 0.3545 - mae: 0.4425 - val_loss: 0.4008 - val_mae: 0.4796 - learning_rate: 0.0020
# Epoch 14/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - loss: 0.3526 - mae: 0.4422 - val_loss: 0.3584 - val_mae: 0.4450 - learning_rate: 0.0020
# Epoch 15/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 151ms/step - loss: 0.3484 - mae: 0.4393 - val_loss: 0.3428 - val_mae: 0.4375 - learning_rate: 0.0020
# Epoch 16/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 17s 120ms/step - loss: 0.3318 - mae: 0.4284 - val_loss: 0.4112 - val_mae: 0.4716 - learning_rate: 0.0020
# Epoch 17/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 0.3356 - mae: 0.4300 - val_loss: 0.3405 - val_mae: 0.4263 - learning_rate: 0.0020
# Epoch 18/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.3353 - mae: 0.4300 - val_loss: 0.3487 - val_mae: 0.4337 - learning_rate: 0.0020
# Epoch 19/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.3242 - mae: 0.4193 - val_loss: 0.3364 - val_mae: 0.4345 - learning_rate: 0.0020
# Epoch 20/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - loss: 0.3249 - mae: 0.4210 - val_loss: 0.3282 - val_mae: 0.4205 - learning_rate: 0.0020
# Epoch 21/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.3311 - mae: 0.4255 - val_loss: 0.3336 - val_mae: 0.4237 - learning_rate: 0.0020
# Epoch 22/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 0.3326 - mae: 0.4257 - val_loss: 0.3253 - val_mae: 0.4331 - learning_rate: 0.0020
# Epoch 23/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.3145 - mae: 0.4136 - val_loss: 0.3096 - val_mae: 0.4113 - learning_rate: 0.0020
# Epoch 24/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.3146 - mae: 0.4119 - val_loss: 0.3538 - val_mae: 0.4473 - learning_rate: 0.0020
# Epoch 25/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.3107 - mae: 0.4110 - val_loss: 0.3603 - val_mae: 0.4317 - learning_rate: 0.0020
# Epoch 26/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 0.3198 - mae: 0.4151 - val_loss: 0.3444 - val_mae: 0.4347 - learning_rate: 0.0020
# Epoch 27/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 0.3085 - mae: 0.4086 - val_loss: 0.3277 - val_mae: 0.4251 - learning_rate: 0.0020
# Epoch 28/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.3132 - mae: 0.4133 - val_loss: 0.3373 - val_mae: 0.4335 - learning_rate: 0.0020
# Epoch 29/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.2932 - mae: 0.3970 - val_loss: 0.3038 - val_mae: 0.4045 - learning_rate: 0.0010
# Epoch 30/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.2902 - mae: 0.3958 - val_loss: 0.3267 - val_mae: 0.4205 - learning_rate: 0.0010
# Epoch 31/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.2867 - mae: 0.3914 - val_loss: 0.3018 - val_mae: 0.3984 - learning_rate: 0.0010
# Epoch 32/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - loss: 0.2869 - mae: 0.3914 - val_loss: 0.2960 - val_mae: 0.3970 - learning_rate: 0.0010
# Epoch 33/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - loss: 0.2885 - mae: 0.3943 - val_loss: 0.3092 - val_mae: 0.4138 - learning_rate: 0.0010
# Epoch 34/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.2875 - mae: 0.3936 - val_loss: 0.3070 - val_mae: 0.4085 - learning_rate: 0.0010
# Epoch 35/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.2846 - mae: 0.3902 - val_loss: 0.3036 - val_mae: 0.4083 - learning_rate: 0.0010
# Epoch 36/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.2819 - mae: 0.3888 - val_loss: 0.3011 - val_mae: 0.3992 - learning_rate: 0.0010
# Epoch 37/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.2899 - mae: 0.3939 - val_loss: 0.2973 - val_mae: 0.3948 - learning_rate: 0.0010
# Epoch 38/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 0.2758 - mae: 0.3828 - val_loss: 0.2955 - val_mae: 0.4009 - learning_rate: 5.0000e-04
# Epoch 39/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 0.2746 - mae: 0.3815 - val_loss: 0.3018 - val_mae: 0.4025 - learning_rate: 5.0000e-04
# Epoch 40/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.2786 - mae: 0.3853 - val_loss: 0.2982 - val_mae: 0.4017 - learning_rate: 5.0000e-04
# Epoch 41/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.2724 - mae: 0.3804 - val_loss: 0.2939 - val_mae: 0.3989 - learning_rate: 5.0000e-04
# Epoch 42/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.2780 - mae: 0.3846 - val_loss: 0.3072 - val_mae: 0.3923 - learning_rate: 5.0000e-04
# Epoch 43/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - loss: 0.2746 - mae: 0.3814 - val_loss: 0.2969 - val_mae: 0.3960 - learning_rate: 5.0000e-04
# Epoch 44/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - loss: 0.2743 - mae: 0.3824 - val_loss: 0.2963 - val_mae: 0.4010 - learning_rate: 5.0000e-04
# Epoch 45/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 0.2744 - mae: 0.3819 - val_loss: 0.3074 - val_mae: 0.4047 - learning_rate: 5.0000e-04
# Epoch 46/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.2708 - mae: 0.3784 - val_loss: 0.2958 - val_mae: 0.3990 - learning_rate: 5.0000e-04
# Epoch 47/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.2669 - mae: 0.3758 - val_loss: 0.2890 - val_mae: 0.3875 - learning_rate: 2.5000e-04
# Epoch 48/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 0.2679 - mae: 0.3759 - val_loss: 0.2945 - val_mae: 0.3994 - learning_rate: 2.5000e-04
# Epoch 49/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.2654 - mae: 0.3746 - val_loss: 0.2874 - val_mae: 0.3912 - learning_rate: 2.5000e-04
# Epoch 50/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.2659 - mae: 0.3746 - val_loss: 0.2899 - val_mae: 0.3908 - learning_rate: 2.5000e-04
# Epoch 51/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 0.2658 - mae: 0.3743 - val_loss: 0.2875 - val_mae: 0.3900 - learning_rate: 2.5000e-04
# Epoch 52/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - loss: 0.2666 - mae: 0.3761 - val_loss: 0.2907 - val_mae: 0.3893 - learning_rate: 2.5000e-04
# Epoch 53/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - loss: 0.2645 - mae: 0.3733 - val_loss: 0.2878 - val_mae: 0.3906 - learning_rate: 2.5000e-04
# Epoch 54/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.2660 - mae: 0.3749 - val_loss: 0.2931 - val_mae: 0.3965 - learning_rate: 2.5000e-04
# Epoch 55/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - loss: 0.2625 - mae: 0.3718 - val_loss: 0.2894 - val_mae: 0.3951 - learning_rate: 1.2500e-04
# Epoch 56/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.2622 - mae: 0.3712 - val_loss: 0.2880 - val_mae: 0.3910 - learning_rate: 1.2500e-04
# Epoch 57/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 0.2623 - mae: 0.3720 - val_loss: 0.2896 - val_mae: 0.3889 - learning_rate: 1.2500e-04
# Epoch 58/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.2616 - mae: 0.3712 - val_loss: 0.2902 - val_mae: 0.3913 - learning_rate: 1.2500e-04
# Epoch 59/80
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - loss: 0.2616 - mae: 0.3716 - val_loss: 0.2881 - val_mae: 0.3940 - learning_rate: 1.2500e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3010 - mae: 0.3960
# {'loss': 0.3010082542896271, 'mae': 0.39596059918403625}
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Artifacts saved to artifacts_cavity_qed
